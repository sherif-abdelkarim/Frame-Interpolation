# %% [markdown]
# # Basic Evaluation of the trained model
# The idea is to compare the predicted missing frame to the linearly interpolated frame, for a given frame gap.

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import h5py
import keras
from keras.models import load_model
from ssim_loss import *
import keras.backend as K

import tensorflow as tf
from ssim_loss import ssim_loss


from skimage.measure import compare_mse as mse
from skimage.measure._structural_similarity import structural_similarity as ssim

# %%
data_sample = "./Aberated/npys/numpy_stack_tomviz_50x50_Deca_Ag_(151, 230, 91)_None_None_None_3_6_3_10.npy"
data_array = np.load(data_sample)
frame = 1

plt.figure()
plt.imshow(data_array[:, :, frame])

# %%
def compute_lin_interpolation(img_block):
    batch_size, h, w, stacked = img_block.shape
    return np.mean(img_block, axis=-1)

def predicted_frame(img_block, model):
    return model.predict(input_block)

def compute_mse(img1, img2):
    assert img1.shape == img2.shape
    batchsize, h, w = img1.shape
    out = 0.
    for item in range(batchsize):
        out += mse(img1[item, :, :], img2[item, :, :])
    return out/batchsize

def compute_ssim(img1, img2):
    assert img1.shape == img2.shape
    batchsize, h, w = img1.shape
    out = 0.
    for item in range(batchsize):
        # same parameters used for training the model
        out += ssim(img1[item, :, :], img2[item, :, :], win_size=11, data_range=1.0, sigma=1.5, k1=0.01, k2=0.03)
    return out/batchsize

# %%
def main(filename, model, batchsize=64):
    ssims = []
    mses = []
    x_axis = []
    x = 0
    f = h5py.File(filename)
    x_val = np.array(f['x_val'])
    y_val = np.array(f['y_val'])
    num_samples = x_val.shape[0]
    for i in range(0, int(num_samples/batchsize)*batchsize, batchsize):
        predicted_frames = model.predict(x_val[i:i+batchsize, :, :, :])
        interpolated_frames = compute_lin_interpolation(x_val[i:i+batchsize, :, :, :])
        target_block = y_val[i:i+batchsize, :, :]
        ssims.append((compute_ssim(predicted_frames, target_block), compute_ssim(interpolated_frames, target_block)))
        mses.append((compute_mse(predicted_frames, target_block), compute_mse(interpolated_frames, target_block)))
        x_axis.append(x)
        x+=1
        if i%10==0:
            print("%d batch are processed, %d are left ..."%(i/64, int(num_samples/batchsize)-(i/64)))
    
    return mses, ssims, x_axis

# %%
model = load_model("frame_gaps_12_aberated_model.h5", {'ssim_loss': ssim_loss})
file_name = "aberrated_hdf5/frame_gaps_4_aberrated.hdf5"

# %%
mses, ssims, x_axis = main(file_name, model, 64)
# Out:
# /home/mohamadt/anaconda/anaconda2/envs/python3/lib/python3.7/site-packages/ipykernel_launcher.py:7: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   import sys
# /home/mohamadt/anaconda/anaconda2/envs/python3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: DEPRECATED: skimage.measure.compare_mse has been moved to skimage.metrics.mean_squared_error. It will be removed from skimage.measure in version 0.18.
#   del sys.path[0]
# 0 batch are processed, 335 are left ...
# 1 batch are processed, 334 are left ...
# 2 batch are processed, 333 are left ...
# 3 batch are processed, 332 are left ...
# 4 batch are processed, 331 are left ...
# 5 batch are processed, 330 are left ...
# 6 batch are processed, 329 are left ...
# 7 batch are processed, 328 are left ...
# 8 batch are processed, 327 are left ...
# 9 batch are processed, 326 are left ...
# 10 batch are processed, 325 are left ...
# 11 batch are processed, 324 are left ...
# 12 batch are processed, 323 are left ...
# 13 batch are processed, 322 are left ...
# 14 batch are processed, 321 are left ...
# 15 batch are processed, 320 are left ...
# 16 batch are processed, 319 are left ...
# 17 batch are processed, 318 are left ...
# 18 batch are processed, 317 are left ...
# 19 batch are processed, 316 are left ...
# 20 batch are processed, 315 are left ...
# 21 batch are processed, 314 are left ...
# 22 batch are processed, 313 are left ...
# 23 batch are processed, 312 are left ...
# 24 batch are processed, 311 are left ...
# 25 batch are processed, 310 are left ...
# 26 batch are processed, 309 are left ...
# 27 batch are processed, 308 are left ...
# 28 batch are processed, 307 are left ...
# 29 batch are processed, 306 are left ...
# 30 batch are processed, 305 are left ...
# 31 batch are processed, 304 are left ...
# 32 batch are processed, 303 are left ...
# 33 batch are processed, 302 are left ...
# 34 batch are processed, 301 are left ...
# 35 batch are processed, 300 are left ...
# 36 batch are processed, 299 are left ...
# 37 batch are processed, 298 are left ...
# 38 batch are processed, 297 are left ...
# 39 batch are processed, 296 are left ...
# 40 batch are processed, 295 are left ...
# 41 batch are processed, 294 are left ...
# 42 batch are processed, 293 are left ...
# 43 batch are processed, 292 are left ...
# 44 batch are processed, 291 are left ...
# 45 batch are processed, 290 are left ...
# 46 batch are processed, 289 are left ...
# 47 batch are processed, 288 are left ...
# 48 batch are processed, 287 are left ...
# 49 batch are processed, 286 are left ...
# 50 batch are processed, 285 are left ...
# 51 batch are processed, 284 are left ...
# 52 batch are processed, 283 are left ...
# 53 batch are processed, 282 are left ...
# 54 batch are processed, 281 are left ...
# 55 batch are processed, 280 are left ...
# 56 batch are processed, 279 are left ...
# 57 batch are processed, 278 are left ...
# 58 batch are processed, 277 are left ...
# 59 batch are processed, 276 are left ...
# 60 batch are processed, 275 are left ...
# 61 batch are processed, 274 are left ...
# 62 batch are processed, 273 are left ...
# 63 batch are processed, 272 are left ...
# 64 batch are processed, 271 are left ...
# 65 batch are processed, 270 are left ...
# 66 batch are processed, 269 are left ...
# 67 batch are processed, 268 are left ...
# 68 batch are processed, 267 are left ...
# 69 batch are processed, 266 are left ...
# 70 batch are processed, 265 are left ...
# 71 batch are processed, 264 are left ...
# 72 batch are processed, 263 are left ...
# 73 batch are processed, 262 are left ...
# 74 batch are processed, 261 are left ...
# 75 batch are processed, 260 are left ...
# 76 batch are processed, 259 are left ...
# 77 batch are processed, 258 are left ...
# 78 batch are processed, 257 are left ...
# 79 batch are processed, 256 are left ...
# 80 batch are processed, 255 are left ...
# 81 batch are processed, 254 are left ...
# 82 batch are processed, 253 are left ...
# 83 batch are processed, 252 are left ...
# 84 batch are processed, 251 are left ...
# 85 batch are processed, 250 are left ...
# 86 batch are processed, 249 are left ...
# 87 batch are processed, 248 are left ...
# 88 batch are processed, 247 are left ...
# 89 batch are processed, 246 are left ...
# 90 batch are processed, 245 are left ...
# 91 batch are processed, 244 are left ...
# 92 batch are processed, 243 are left ...
# 93 batch are processed, 242 are left ...
# 94 batch are processed, 241 are left ...
# 95 batch are processed, 240 are left ...
# 96 batch are processed, 239 are left ...
# 97 batch are processed, 238 are left ...
# 98 batch are processed, 237 are left ...
# 99 batch are processed, 236 are left ...
# 100 batch are processed, 235 are left ...
# 101 batch are processed, 234 are left ...
# 102 batch are processed, 233 are left ...
# 103 batch are processed, 232 are left ...
# 104 batch are processed, 231 are left ...
# 105 batch are processed, 230 are left ...
# 106 batch are processed, 229 are left ...
# 107 batch are processed, 228 are left ...
# 108 batch are processed, 227 are left ...
# 109 batch are processed, 226 are left ...
# 110 batch are processed, 225 are left ...
# 111 batch are processed, 224 are left ...
# 112 batch are processed, 223 are left ...
# 113 batch are processed, 222 are left ...
# 114 batch are processed, 221 are left ...
# 115 batch are processed, 220 are left ...
# 116 batch are processed, 219 are left ...
# 117 batch are processed, 218 are left ...
# 118 batch are processed, 217 are left ...
# 119 batch are processed, 216 are left ...
# 120 batch are processed, 215 are left ...
# 121 batch are processed, 214 are left ...
# 122 batch are processed, 213 are left ...
# 123 batch are processed, 212 are left ...
# 124 batch are processed, 211 are left ...
# 125 batch are processed, 210 are left ...
# 126 batch are processed, 209 are left ...
# 127 batch are processed, 208 are left ...
# 128 batch are processed, 207 are left ...
# 129 batch are processed, 206 are left ...
# 130 batch are processed, 205 are left ...
# 131 batch are processed, 204 are left ...
# 132 batch are processed, 203 are left ...
# 133 batch are processed, 202 are left ...
# 134 batch are processed, 201 are left ...
# 135 batch are processed, 200 are left ...
# 136 batch are processed, 199 are left ...
# 137 batch are processed, 198 are left ...
# 138 batch are processed, 197 are left ...
# 139 batch are processed, 196 are left ...
# 140 batch are processed, 195 are left ...
# 141 batch are processed, 194 are left ...
# 142 batch are processed, 193 are left ...
# 143 batch are processed, 192 are left ...
# 144 batch are processed, 191 are left ...
# 145 batch are processed, 190 are left ...
# 146 batch are processed, 189 are left ...
# 147 batch are processed, 188 are left ...
# 148 batch are processed, 187 are left ...
# 149 batch are processed, 186 are left ...
# 150 batch are processed, 185 are left ...
# 151 batch are processed, 184 are left ...
# 152 batch are processed, 183 are left ...
# 153 batch are processed, 182 are left ...
# 154 batch are processed, 181 are left ...
# 155 batch are processed, 180 are left ...
# 156 batch are processed, 179 are left ...
# 157 batch are processed, 178 are left ...
# 158 batch are processed, 177 are left ...
# 159 batch are processed, 176 are left ...
# 160 batch are processed, 175 are left ...
# 161 batch are processed, 174 are left ...
# 162 batch are processed, 173 are left ...
# 163 batch are processed, 172 are left ...
# 164 batch are processed, 171 are left ...
# 165 batch are processed, 170 are left ...
# 166 batch are processed, 169 are left ...
# 167 batch are processed, 168 are left ...
# 168 batch are processed, 167 are left ...
# 169 batch are processed, 166 are left ...
# 170 batch are processed, 165 are left ...
# 171 batch are processed, 164 are left ...
# 172 batch are processed, 163 are left ...
# 173 batch are processed, 162 are left ...
# 174 batch are processed, 161 are left ...
# 175 batch are processed, 160 are left ...
# 176 batch are processed, 159 are left ...
# 177 batch are processed, 158 are left ...
# 178 batch are processed, 157 are left ...
# 179 batch are processed, 156 are left ...
# 180 batch are processed, 155 are left ...
# 181 batch are processed, 154 are left ...
# 182 batch are processed, 153 are left ...
# 183 batch are processed, 152 are left ...
# 184 batch are processed, 151 are left ...
# 185 batch are processed, 150 are left ...
# 186 batch are processed, 149 are left ...
# 187 batch are processed, 148 are left ...
# 188 batch are processed, 147 are left ...
# 189 batch are processed, 146 are left ...
# 190 batch are processed, 145 are left ...
# 191 batch are processed, 144 are left ...
# 192 batch are processed, 143 are left ...
# 193 batch are processed, 142 are left ...
# 194 batch are processed, 141 are left ...
# 195 batch are processed, 140 are left ...
# 196 batch are processed, 139 are left ...
# 197 batch are processed, 138 are left ...
# 198 batch are processed, 137 are left ...
# 199 batch are processed, 136 are left ...
# 200 batch are processed, 135 are left ...
# 201 batch are processed, 134 are left ...
# 202 batch are processed, 133 are left ...
# 203 batch are processed, 132 are left ...
# 204 batch are processed, 131 are left ...
# 205 batch are processed, 130 are left ...
# 206 batch are processed, 129 are left ...
# 207 batch are processed, 128 are left ...
# 208 batch are processed, 127 are left ...
# 209 batch are processed, 126 are left ...
# 210 batch are processed, 125 are left ...
# 211 batch are processed, 124 are left ...
# 212 batch are processed, 123 are left ...
# 213 batch are processed, 122 are left ...
# 214 batch are processed, 121 are left ...
# 215 batch are processed, 120 are left ...
# 216 batch are processed, 119 are left ...
# 217 batch are processed, 118 are left ...
# 218 batch are processed, 117 are left ...
# 219 batch are processed, 116 are left ...
# 220 batch are processed, 115 are left ...
# 221 batch are processed, 114 are left ...
# 222 batch are processed, 113 are left ...
# 223 batch are processed, 112 are left ...
# 224 batch are processed, 111 are left ...
# 225 batch are processed, 110 are left ...
# 226 batch are processed, 109 are left ...
# 227 batch are processed, 108 are left ...
# 228 batch are processed, 107 are left ...
# 229 batch are processed, 106 are left ...
# 230 batch are processed, 105 are left ...
# 231 batch are processed, 104 are left ...
# 232 batch are processed, 103 are left ...
# 233 batch are processed, 102 are left ...
# 234 batch are processed, 101 are left ...
# 235 batch are processed, 100 are left ...
# 236 batch are processed, 99 are left ...
# 237 batch are processed, 98 are left ...
# 238 batch are processed, 97 are left ...
# 239 batch are processed, 96 are left ...
# 240 batch are processed, 95 are left ...
# 241 batch are processed, 94 are left ...
# 242 batch are processed, 93 are left ...
# 243 batch are processed, 92 are left ...
# 244 batch are processed, 91 are left ...
# 245 batch are processed, 90 are left ...
# 246 batch are processed, 89 are left ...
# 247 batch are processed, 88 are left ...
# 248 batch are processed, 87 are left ...
# 249 batch are processed, 86 are left ...
# 250 batch are processed, 85 are left ...
# 251 batch are processed, 84 are left ...
# 252 batch are processed, 83 are left ...
# 253 batch are processed, 82 are left ...
# 254 batch are processed, 81 are left ...
# 255 batch are processed, 80 are left ...
# 256 batch are processed, 79 are left ...
# 257 batch are processed, 78 are left ...
# 258 batch are processed, 77 are left ...
# 259 batch are processed, 76 are left ...
# 260 batch are processed, 75 are left ...
# 261 batch are processed, 74 are left ...
# 262 batch are processed, 73 are left ...
# 263 batch are processed, 72 are left ...
# 264 batch are processed, 71 are left ...
# 265 batch are processed, 70 are left ...
# 266 batch are processed, 69 are left ...
# 267 batch are processed, 68 are left ...
# 268 batch are processed, 67 are left ...
# 269 batch are processed, 66 are left ...
# 270 batch are processed, 65 are left ...
# 271 batch are processed, 64 are left ...
# 272 batch are processed, 63 are left ...
# 273 batch are processed, 62 are left ...
# 274 batch are processed, 61 are left ...
# 275 batch are processed, 60 are left ...
# 276 batch are processed, 59 are left ...
# 277 batch are processed, 58 are left ...
# 278 batch are processed, 57 are left ...
# 279 batch are processed, 56 are left ...
# 280 batch are processed, 55 are left ...
# 281 batch are processed, 54 are left ...
# 282 batch are processed, 53 are left ...
# 283 batch are processed, 52 are left ...
# 284 batch are processed, 51 are left ...
# 285 batch are processed, 50 are left ...
# 286 batch are processed, 49 are left ...
# 287 batch are processed, 48 are left ...
# 288 batch are processed, 47 are left ...
# 289 batch are processed, 46 are left ...
# 290 batch are processed, 45 are left ...
# 291 batch are processed, 44 are left ...
# 292 batch are processed, 43 are left ...
# 293 batch are processed, 42 are left ...
# 294 batch are processed, 41 are left ...
# 295 batch are processed, 40 are left ...
# 296 batch are processed, 39 are left ...
# 297 batch are processed, 38 are left ...
# 298 batch are processed, 37 are left ...
# 299 batch are processed, 36 are left ...
# 300 batch are processed, 35 are left ...
# 301 batch are processed, 34 are left ...
# 302 batch are processed, 33 are left ...
# 303 batch are processed, 32 are left ...
# 304 batch are processed, 31 are left ...
# 305 batch are processed, 30 are left ...
# 306 batch are processed, 29 are left ...
# 307 batch are processed, 28 are left ...
# 308 batch are processed, 27 are left ...
# 309 batch are processed, 26 are left ...
# 310 batch are processed, 25 are left ...
# 311 batch are processed, 24 are left ...
# 312 batch are processed, 23 are left ...
# 313 batch are processed, 22 are left ...
# 314 batch are processed, 21 are left ...
# 315 batch are processed, 20 are left ...
# 316 batch are processed, 19 are left ...
# 317 batch are processed, 18 are left ...
# 318 batch are processed, 17 are left ...
# 319 batch are processed, 16 are left ...
# 320 batch are processed, 15 are left ...
# 321 batch are processed, 14 are left ...
# 322 batch are processed, 13 are left ...
# 323 batch are processed, 12 are left ...
# 324 batch are processed, 11 are left ...
# 325 batch are processed, 10 are left ...
# 326 batch are processed, 9 are left ...
# 327 batch are processed, 8 are left ...
# 328 batch are processed, 7 are left ...
# 329 batch are processed, 6 are left ...
# 330 batch are processed, 5 are left ...
# 331 batch are processed, 4 are left ...
# 332 batch are processed, 3 are left ...
# 333 batch are processed, 2 are left ...
# 334 batch are processed, 1 are left ...

# %%
fig, axs = plt.subplots(2, 1, figsize=(20,10))

axs[0].plot(x_axis, [i[0] for i in mses], label="Patch CNN")
axs[0].plot(x_axis, [i[1] for i in mses], label="lin interpolation")
axs[0].set_title('MSE')
axs[0].legend()
axs[1].plot(x_axis, [i[0] for i in ssims], label="Patch CNN")
axs[1].plot(x_axis, [i[1] for i in ssims], label="lin interpolation")
axs[1].set_title('SSIM')
axs[1].legend()
